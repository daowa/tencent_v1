# %%
import pandas as pd
import numpy as np
data = pd.read_csv("E:\\work\\kaggle\\data\\tecent\\pre\\app_categories.csv")
data
# Out:
#          appID  appCategory
# 0           14            2
# 1           25          203
# 2           68          104
# 3           75          402
# 4           83          203
# 5           84          402
# 6           88          203
# 7          100          301
# 8          105          301
# 9          109          407
# 10         113          104
# 11         116          402
# 12         123          104
# 13         127          101
# 14         137          301
# 15         146          104
# 16         150          104
# 17         160          408
# 18         195          104
# 19         198          104
# 20         205          101
# 21         206          106
# 22         218          104
# 23         229          104
# 24         262            0
# 25         271          101
# 26         278          104
# 27         283          104
# 28         284          101
# 29         286          104
# ...        ...          ...
# 217011  433120          503
# ...
