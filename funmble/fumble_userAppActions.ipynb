# %%
import pandas as pd
import numpy as np
data = pd.read_csv("C:\\Users\\work\\Desktop\\tencent\\pre\\user_app_actions.csv")
data.head()
# Out:
#    userID  installTime  appID
# 0       1       182032    933
# 1       5       141354    589
# 2       5       251727    565
# 3       5       260932    596
# 4       5       261318    536

# %%
temp = data.sort_values(by='appID')

# %%
temp[temp['appID']==354]
# Out:
#           userID  installTime  appID
# 4867260  2271305       301514    354
# 1856893   871917       132016    354
# 4243357  1979632       152007    354
# 3953292  1845041       212141    354
# 5650570  2639794       110040    354
# 2208991  1035955       101159    354
# 286978    135764        51647    354
# 752714    354828       111548    354
# 861472    406893        52338    354
# 4352868  2029880        21528    354
# 2740990  1283665       121124    354
# 2194968  1029576       101844    354
# 1695052   796232       142047    354
# 3648688  1704242       111845    354
# 1638739   770388       222113    354
# 4421185  2062117       112209    354
# 790585    372839       131529    354
# 3527314  1647141       171803    354
# 3537857  1651951       110911    354
# 5517553  2576699       260205    354
# 4330038  2019508        71702    354
# 51248      23837       102210    354
# 2150167  1008424       110918    354
# 1997921   937153        81924    354
# ...
